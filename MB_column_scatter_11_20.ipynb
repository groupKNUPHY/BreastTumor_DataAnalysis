# %%
import pandas as pd
import matplotlib.pyplot as plt

change = []
df = pd.read_csv("/home/xoqhdgh/data.csv")
df = df.iloc[:,:-1]

for i in df['diagnosis']:
    if i == 'M':
        change = change + [1]
    else:
        change = change + [0]

plt.scatter(df['radius_se'],change)
plt.show()

# %%
change = []
df = pd.read_csv("/home/xoqhdgh/data.csv")
df = df.iloc[:,:-1]

for i in df['diagnosis']:
    if i == 'M':
        change.append(1)
    else:
        change.append(0)

plt.scatter(df['texture_se'],change)
plt.show()

# %%
change = []
df = pd.read_csv("/home/xoqhdgh/data.csv")
df = df.iloc[:,:-1]

for i in df['diagnosis']:
    if i == 'M':
        change.append(1)
    else:
        change.append(0)

plt.scatter(df['perimeter_se'],change)
plt.show()

# %%
change = []
df = pd.read_csv("/home/xoqhdgh/data.csv")
df = df.iloc[:,:-1]

for i in df['diagnosis']:
    if i == 'M':
        change.append(1)
    else:
        change.append(0)

plt.scatter(df['area_se'],change)
plt.show()

# %%
change = []
df = pd.read_csv("/home/xoqhdgh/data.csv")
df = df.iloc[:,:-1]

for i in df['diagnosis']:
    if i == 'M':
        change.append(1)
    else:
        change.append(0)

plt.scatter(df['smoothness_se'],change)
plt.show()

# %%
change = []
df = pd.read_csv("/home/xoqhdgh/data.csv")
df = df.iloc[:,:-1]

for i in df['diagnosis']:
    if i == 'M':
        change.append(1)
    else:
        change.append(0)

plt.scatter(df['compactness_se'],change)
plt.show()

# %%
change = []
df = pd.read_csv("/home/xoqhdgh/data.csv")
df = df.iloc[:,:-1]

for i in df['diagnosis']:
    if i == 'M':
        change.append(1)
    else:
        change.append(0)

plt.scatter(df['concavity_se'],change)
plt.show()

# %%
change = []
df = pd.read_csv("/home/xoqhdgh/data.csv")
df = df.iloc[:,:-1]

for i in df['diagnosis']:
    if i == 'M':
        change.append(1)
    else:
        change.append(0)

plt.scatter(df['concave points_se'],change)
plt.show()

# %%
change = []
df = pd.read_csv("/home/xoqhdgh/data.csv")
df = df.iloc[:,:-1]

for i in df['diagnosis']:
    if i == 'M':
        change.append(1)
    else:
        change.append(0)

plt.scatter(df['symmetry_se'],change)
plt.show()

# %%
change = []
df = pd.read_csv("/home/xoqhdgh/data.csv")
df = df.iloc[:,:-1]

for i in df['diagnosis']:
    if i == 'M':
        change.append(1)
    else:
        change.append(0)

plt.scatter(df['fractal_dimension_se'],change)
plt.show()
